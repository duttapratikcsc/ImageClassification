# %% [markdown]
# <a href="https://colab.research.google.com/github/duttapratikcsc/NPTEL/blob/master/Regression_PredictFuelEfficiency/Auto_MPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install prerequisite packages and import**

# %%
# !pip install seaborn
# !pip install tensorflow==2.0.0-beta1

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)

# %% [markdown]
# #**Get the Auto MPG Dataset from keras and load into module using pandas**

# %%
dataset_path = keras.utils.get_file("auto-mpg.data", "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset_path
# Out:
# ...
# 32768/30286 [================================] - 0s 1us/step
# '/root/.keras/datasets/auto-mpg.data'

# %%
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']
raw_dataset = pd.read_csv(dataset_path, names=column_names,
                          na_values = '?', comment='\t',
                          sep=" ", skipinitialspace=True)
dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  ...  Acceleration  Model Year  Origin
# 393  27.0          4         140.0  ...          15.6          82       1
# 394  44.0          4          97.0  ...          24.6          82       2
# 395  32.0          4         135.0  ...          11.6          82       1
# 396  28.0          4         120.0  ...          18.6          82       1
# 397  31.0          4         119.0  ...          19.4          82       1
#
# [5 rows x 8 columns]

# %% [markdown]
# # **Preprocessing Data**
#
# 1.   Cleaning Data

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
dataset = dataset.dropna()

# %% [markdown]
# The "Origin" Column is really categorical, not numeric. So convert that into a one-hot.

# %%
origin = dataset.pop('Origin')

# %%
dataset['USA'] = (origin == 1)*1.0
dataset['Europe'] = (origin == 2)*1.0
dataset['Japan'] = (origin == 3)*1.0
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  ...  Model Year  USA  Europe  Japan
# 393  27.0          4         140.0        86.0  ...          82  1.0     0.0    0.0
# 394  44.0          4          97.0        52.0  ...          82  0.0     1.0    0.0
# 395  32.0          4         135.0        84.0  ...          82  1.0     0.0    0.0
# 396  28.0          4         120.0        79.0  ...          82  1.0     0.0    0.0
# 397  31.0          4         119.0        82.0  ...          82  1.0     0.0    0.0
#
# [5 rows x 10 columns]

# %% [markdown]
# # **Split the data into train and test**

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# # **Inspect the data**
#
#
#
#
#
#
#
# ---
#
# Have a quick look the joint distribution of few pairs of columns from the training set.

# %%
sns.pairplot(train_dataset[["MPG", "Cylinders", "Displacement", "Horsepower", "Weight", "Acceleration", "Model Year"]], diag_kind="kde")

# %% [markdown]
# Look at the overall statistics

# %%
train_stats = train_dataset.describe()
train_stats.pop("MPG")
train_stats = train_stats.transpose()
train_stats
# Out:
#               count         mean         std  ...     50%      75%     max
# Cylinders     314.0     5.477707    1.699788  ...     4.0     8.00     8.0
# Displacement  314.0   195.318471  104.331589  ...   151.0   265.75   455.0
# Horsepower    314.0   104.869427   38.096214  ...    94.5   128.00   225.0
# Weight        314.0  2990.251592  843.898596  ...  2822.5  3608.00  5140.0
# Acceleration  314.0    15.559236    2.789230  ...    15.5    17.20    24.8
# Model Year    314.0    75.898089    3.675642  ...    76.0    79.00    82.0
# USA           314.0     0.624204    0.485101  ...     1.0     1.00     1.0
# Europe        314.0     0.178344    0.383413  ...     0.0     0.00     1.0
# Japan         314.0     0.197452    0.398712  ...     0.0     0.00     1.0
#
# [9 rows x 8 columns]

# %% [markdown]
# # **Split features from labels**
#
#
# ---
#
#
#
# Seperate the target value, or "label", from the features. This label is the value that you will train teh valur that you will train the model to predict.

# %%
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

# %% [markdown]
# # **Normalize the data**

# %%
def norm(x):
  return (x - train_stats['mean'])/train_stats['std']

normalized_train_data = norm(train_dataset)
normalized_test_data = norm(test_dataset)

# %% [markdown]
# Again, look at the overall normalized statistics

# %%
normalized_train_stats = normalized_train_data.describe()
normalized_train_stats = normalized_train_stats.transpose()
normalized_train_stats
# Out:
#               count          mean  std  ...       50%       75%       max
# Cylinders     314.0  2.093159e-16  1.0  ... -0.869348  1.483887  1.483887
# Displacement  314.0  1.018294e-16  1.0  ... -0.424785  0.675074  2.489002
# Horsepower    314.0 -1.909301e-17  1.0  ... -0.272190  0.607162  3.153347
# Weight        314.0 -9.723291e-17  1.0  ... -0.198782  0.732017  2.547401
# Acceleration  314.0  2.688832e-15  1.0  ... -0.021237  0.588250  3.313017
# Model Year    314.0  9.561531e-16  1.0  ...  0.027726  0.843910  1.660094
# USA           314.0  6.081476e-17  1.0  ...  0.774676  0.774676  0.774676
# Europe        314.0  8.485781e-18  1.0  ... -0.465148 -0.465148  2.143005
# Japan         314.0  3.164489e-17  1.0  ... -0.495225 -0.495225  2.012852
#
# [9 rows x 8 columns]

# %% [markdown]
# # **The Model**

# %%
def build_model():
  model = keras.Sequential([
                            layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
                            layers.Dense(64, activation='relu'),
                            layers.Dense(1)
  ])

  optimizer = keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %% [markdown]
# # **Inspect the model**

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 64)                640
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# ...
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normalized_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[ 0.02111819],
#        [ 0.06260502],
#        [-1.0455095 ],
#        [ 0.16351953],
#        [-0.36424363],
#        [-0.09544641],
#        [-0.35151976],
#        [-0.22952148],
#        [-0.04960853],
#        [-0.46359405]], dtype=float32)

# %% [markdown]
# # **Train the model**

# %%
#Display training progressby printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch %100 == 0: print(' ')
    print('.', end='')

EPOCHS=1000

history = model.fit(
    normalized_train_data, train_labels,
    epochs=EPOCHS, validation_split = 0.2, verbose=0,
    callbacks=[PrintDot()], batch_size=10
)
# Out:
#
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ...

# %%
hist = pd.DataFrame(history.history)
#hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse   val_loss   val_mae    val_mse
# 995  0.964821  0.593151  0.964821  20.315936  3.246658  20.315935
# 996  0.918979  0.601655  0.918979  20.384138  3.350534  20.384140
# 997  0.852803  0.591498  0.852803  21.863602  3.227944  21.863602
# 998  0.961635  0.603622  0.961635  20.030175  3.309092  20.030176
# 999  1.006293  0.626614  1.006292  22.784521  3.550327  22.784521

# %%
 def plot_history(history):
   hist = pd.DataFrame(history.history)
   hist['epoch'] = history.epoch

   plt.figure()
   plt.xlabel('Epoch')
   plt.ylabel('Mean Abs Error [MPG]')
   plt.plot(hist['epoch'], hist['mae'],
            label='Train Error')
   plt.plot(hist['epoch'], hist['val_mae'],
            label= 'Val Error')
   plt.ylim([0,5])
   plt.legend()

   plt.figure()
   plt.xlabel('Epoch')
   plt.ylabel('Mean Square Error [$MPG^2$]')
   plt.plot(hist['epoch'], hist['mse'],
            label='Train Error')
   plt.plot(hist['epoch'], hist['val_mse'],
            label= 'Val Error')
   plt.ylim([0,20])
   plt.legend()
   plt.show()

# %%
plot_history(history)

# %%
model = build_model()

#The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

new_history = model.fit(
    normalized_train_data, train_labels,
    epochs=EPOCHS, validation_split = 0.2, verbose=0,
    callbacks=[early_stop, PrintDot()]
)

plot_history(new_history)
# Out:
#
# .............................................................................

# %%
loss, mae, mse = model.evaluate(normalized_test_data, test_labels, verbose=0)
print("Testing set Mean Abs Error: {:5.2f} MPG".format(mae))
# Out:
# Testing set Mean Abs Error:  1.87 MPG

# %% [markdown]
# # **Make Predictions**

# %%
test_predictions = model.predict(normalized_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
plt.plot(test_labels.values, label='True Value')
plt.plot(test_predictions, label='Predicted Value')
plt.legend()
plt.xlabel('Test Data')
# Out:
# Text(0.5, 0, 'Test Data')

# %%
error = test_predictions - test_labels
plt.hist(error, bins = 40)
plt.xlabel("Prediction Error [MPG]")
_ = plt.ylabel("Count")
